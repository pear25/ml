# %%
import numpy as np

arr = np.array([-1000.0, 0.0, 10030.0])
v = np.e ** -arr

# print(v)
res = 1 / (1 + v)
print(res)
# Out:
# [0.  0.5 1. ]
# /var/folders/vv/8sgh_t3j7bq4gm171plzwfy40000gn/T/ipykernel_79703/1368174859.py:4: RuntimeWarning: overflow encountered in power
#   v = np.e ** -arr

# %%
# Form 2 to negate infinity error

arr_2 = np.array([-1000.0, 0.0, 10030.0])

# v2 = np.exp(-arr_2)
# factor = np.exp(arr_2)

# form_a = 1 / (1 + v2)
# form_b = (factor) / ((1 + factor))
s = np.exp(-np.abs(arr_2))


form_a = 1 / (1 + s)
form_b = s / (1 + s)

res = np.where(arr_2 >= 0, form_a, form_b)
print(res)

# res = np.where(arr_2 >= 0, form_a, form_b)


# print(res)
# Out:
# [0.  0.5 1. ]
